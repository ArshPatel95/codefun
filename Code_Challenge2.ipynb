# %%
words = ['stacked','bored' ,'kayak', 'deified',
 'rotator' ,'repaper', 'deed', 'peep' ,'wow' ,'noon',
 'fried', 'turkeys', 'batton', 'tiger','lions', 'bears']

# %%
words2 = words [::-1]
words2
# Out:
# ['bears',
#  'lions',
#  'tiger',
#  'batton',
#  'turkeys',
#  'fried',
#  'noon',
#  'wow',
#  'peep',
#  'deed',
#  'repaper',
#  'rotator',
#  'deified',
#  'kayak',
#  'bored',
#  'stacked']

# %%
words.reverse()

# %%
words
# Out:
# ['bears',
#  'lions',
#  'tiger',
#  'batton',
#  'turkeys',
#  'fried',
#  'noon',
#  'wow',
#  'peep',
#  'deed',
#  'repaper',
#  'rotator',
#  'deified',
#  'kayak',
#  'bored',
#  'stacked']

# %%
def palindrome():
    return x[::-1]
newpalindrome = palindrome(words)

print(newpalindrome)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2ea071c4f5ee> in <module>
#       1 def palindrome():
#       2     return x[::-1]
# ----> 3 newpalindrome = palindrome(words)
#       4
#       5 print(newpalindrome)
#
# TypeError: palindrome() takes 0 positional arguments but 1 was given

# %%
words = ['stacked','bored' ,'kayak', 'deified',
 'rotator' ,'repaper', 'deed', 'peep' ,'wow' ,'noon',
 'fried', 'turkeys', 'batton', 'tiger','lions', 'bears']
newdict = {'palindrome':[],'not palindrome':[]}
for word in words:
    if word == word[::-1]:
        word_state = 'palindrome'
    else:
        word_state = 'not palindrome'
    newdict[word_state].append(word)
print(newdict)
# Out:
# {'palindrome': ['kayak', 'deified', 'rotator', 'repaper', 'deed', 'peep', 'wow', 'noon'], 'not palindrome': ['stacked', 'bored', 'fried', 'turkeys', 'batton', 'tiger', 'lions', 'bears']}
